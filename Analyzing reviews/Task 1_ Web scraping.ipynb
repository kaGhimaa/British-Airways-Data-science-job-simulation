# %% [markdown]
# # Task 1: Web scraping

# %% [markdown]
# ## Step 01 : importing libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Step 02 : setup for the scraping

# %%
# since we want to import the reviews about british airways we'll visit the website called "airlinequality" and search "british airways " and use that link 
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 10 
page_size = 100

reviews = []

# %% [markdown]
# ## Step 03 : collecting the data

# %%
for i in range(1, pages + 1):
    print("we're scraping page number " , i )
    # we notice that the link of second page is "https://www.airlinequality.com/airline-reviews/british-airways/page/2/?sortby=post_date%3ADesc&pagesize=100" we can generalize this link to collect all coming links 'Navigate through pages ' 
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"
    # we start collecting html data 
    response = requests.get(url)
    
    #parsing the content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for par in parsed_content.find_all("div", {'class' : 'text_content'}):
        reviews.append(par.get_text())
    print(f"   ---> {len(reviews)} total reviews")
# Out:
# we're scraping page number  1
#    ---> 100 total reviews
# we're scraping page number  2
#    ---> 200 total reviews
# we're scraping page number  3
#    ---> 300 total reviews
# we're scraping page number  4
#    ---> 400 total reviews
# we're scraping page number  5
#    ---> 500 total reviews
# we're scraping page number  6
#    ---> 600 total reviews
# we're scraping page number  7
#    ---> 700 total reviews
# we're scraping page number  8
#    ---> 800 total reviews
# we're scraping page number  9
#    ---> 900 total reviews
# we're scraping page number  10
#    ---> 1000 total reviews

# %% [markdown]
# ## Step 04 : saving results in a dataframe

# %%
df = pd.DataFrame()
df['reviews'] = reviews
df.head()
# Out:
#                                              reviews
# 0  ✅ Trip Verified |  Starting off at Heathrow Te...
# 1  Not Verified |  We have flown this route with ...
# 2  ✅ Trip Verified | A last minute business trip ...
# 3  ✅ Trip Verified |   Overall I would say disapp...
# 4  Not Verified |  LHR to Delhi in Business. Exce...

# %% [markdown]
# ## Step 05 : saving df to csv file

# %%
df.to_csv('British_Airways_reviews')
